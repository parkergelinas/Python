# %%
import requests
base_url = "https://api.binance.com"
path = "/api/v3/klines"
r = requests.get(base_url+path, params = {'symbol':'BTCUSDT','interval':'1m'})
r.json()
# Out:
# [[1654380600000,
#   '29917.79000000',
#   '29934.72000000',
#   '29917.79000000',
#   '29932.70000000',
#   '51.59165000',
#   1654380659999,
#   '1543982.52945430',
#   633,
#   '34.92027000',
#   '1045005.75678310',
#   '0'],
#  [1654380660000,
#   '29932.70000000',
#   '29939.36000000',
#   '29922.29000000',
#   '29937.74000000',
#   '33.73310000',
#   1654380719999,
#   '1009651.52702550',
#   665,
#   '14.57967000',
#   '436353.86448890',
#   '0'],
#  [1654380720000,
#   '29937.74000000',
#   '29960.00000000',
#   '29936.74000000',
#   '29950.78000000',
#   '36.96490000',
#   1654380779999,
#   '1106994.95983810',
#   943,
#   '26.34256000',
#   '788861.68184690',
#   '0'],
#  [1654380780000,
#   '29950.79000000',
#   '29977.99000000',
#   '29933.54000000',
#   '29933.54000000',
#   '34.44037000',
#   1654380839999,
#   '1031594.08546520',
#   1151,
#   '15.37641000',
#   '460615.73760230',
#   '0'],
#  [1654380840000,
#   '29933.55000000',
#   '29935.41000000',
# ...

# %%
r.json()
